# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import gamma
from scipy.misc import factorial
from scipy.stats import norm
from scipy.stats import multivariate_normal
from scipy.optimize import minimize
from matplotlib import animation, rc
from IPython.display import HTML
import base64
import cv2 as cv
from skimage.transform import resize
from IPython.core.display import HTML
figSize = 5

# %%
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;}
# </style>

# %% [markdown]
# # Population Receptive Field Estimation Technique Simulation
#
# The aim of this computational neuroscience research project is to develope and simulate novel neuroimaging techniques for estimating PRF of human visual field using simulation.
# The outline of the work can be summed up as such,
#
# * Simulation Data
#     * Creating bar stimulus 3D array
#     * Retinotopic Mapping
#     * Experiment Parmeters
#     * Modelling BOLD Response
#     * Downsampling to fMRI resolution
#
# * Estimate the assumed PRF from simulated fMRI data
# * Compare Assumed model with estimations
# * Repeat with better stimulus protocol

# %% [markdown]
# # 1. Simulation Data
# First we are going to generate the stimulus protocol.
#
# ## 1.1. Creating bar stimulus 3D array

# %%
radius = 10.1
precession = 0.1
barWidth = radius / 4
angles = [-90, 45, -180, 315, 90, 225, 0, 135]
nFrames = len(angles)*3
TRs = 5 # number of TRs for each frame



X = Y = np.arange(-radius, radius , precession)
length = len(X)
stim = np.zeros((nFrames, length, length))
stim_transformed = np.zeros((nFrames*TRs, length, length))

f = 0
for angle in angles:
    for k in range(3):
        for i, x in enumerate(X):
            for j, y in enumerate(Y):
                if np.sin(np.deg2rad(angle))*x - np.cos(np.deg2rad(angle))*y <= (0.5-0.5*k)*radius + barWidth:
                    if np.sin(np.deg2rad(angle))*x - np.cos(np.deg2rad(angle))*y >= (0.5-0.5*k)*radius - barWidth:
                        for TR in range(TRs):
                            stim[f*TRs + TR, j, i] = 1
                            stim_transformed[f*TRs + TR, ]
        # updates the frame
        f = f + 1

# %% [markdown]
# ### Description and animation of stimulus
# Drifting bar apertures at various orientations used in Dumoulin(2007) paper; The bar width subtended 1/4th of the stimulus radius. Four bar orientations and two different motion directions for each bar were used, giving a total of 8 different bar with 3 diffrent location which gives 24 configurations within a given scan as shown bellow.
# ![barStim.png](attachment:barStim.png)

# %%
fig = plt.figure(figsize=(figSize, figSize))
ax = plt.axes()  

# Animation function
def animate(i): 
    z = stim[i,:,:]
    cont = plt.contourf(X, Y, z)

    return cont  

anim = animation.FuncAnimation(fig, animate, frames=nFrames)

anim.save('stimulus.mp4', writer = 'ffmpeg', fps=1, codec='libx264')

with open('stimulus.mp4', 'rb') as f:
    video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(base64.b64encode(f.read()).decode('utf-8'))
    
plt.close()   
HTML(video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %% [markdown]
# ### Plot of overall visual field covered

# %%
fig = plt.figure(figsize=(figSize, figSize))
shape2D = (len(X), len(Y))
proj2D = np.zeros(shape2D)
for i in range(nFrames):
    proj2D = proj2D + (stim[i, :, :]).reshape(shape2D)
    
plt.imshow(proj2D)

# %% [markdown]
# ## 1.2. Retinotopic Mapping
# The retinotopic mapping can be moddeled using the log-polar transformation $dst( \rho , \phi ) = src(x, y)$ which emulates the human “foveal” vision where,
#
# $$
# \begin{array}{l}
# \rho = M \cdot \ln{\sqrt{x^2 + y^2}}\\
# \phi = \arctan{\frac{y}{x}}  \\
# \end{array}
# $$
#
# M – Magnitude scale parameter. It determines the radius of the bounding circle to transform too.
#
# ### Demonstration
# We can do a forward and backward transformation on a sample image to show the cortical zooming effect which is emulates the behaviour of fovea.

# %%
fig = plt.figure(figsize=(figSize, figSize))
img_test = cv.imread('lenna.png', 0)
plt.imshow(img_test)

# %%
M = 20
fig = plt.figure(figsize=(figSize, figSize))
center = (img_test.shape[0]/2, img_test.shape[1]/2)

warped_img = cv.logPolar(img_test, center, M, cv.WARP_FILL_OUTLIERS)
back_img = cv.logPolar(warped_img, center, M, cv.WARP_INVERSE_MAP + cv.WARP_FILL_OUTLIERS)

plt.imshow(warped_img)

# %%
fig = plt.figure(figsize=(figSize, figSize))
plt.imshow(back_img)

# %% [markdown]
# ### Stimulus Mapping

# %%
M = 20
center_left = (stim.shape[2]/2, stim.shape[1]/2)
center_right = (stim.shape[2]/2, stim.shape[1]/2)
stim_left = np.zeros(stim.shape)
stim_right = np.zeros(stim.shape)
logpolar_stim_left = np.zeros(stim.shape)
logpolar_stim_right = np.zeros(stim.shape)
logpolar_stim = np.zeros(stim.shape)
recovered_stim = np.zeros(stim.shape)

for frame in range(nFrames):
    img = np.flipud(stim[frame, :, :])
    x_half = int(img.shape[1]/2)
    
    # dividing the stimulus into left and right
    stim_left[frame, :, 0:x_half] = img[:, 0:x_half]
    stim_right[frame, :, x_half:] = img[:, x_half:]
    stim_right[frame] = np.fliplr(stim_right[frame])
    
    logpolar_stim_left[frame, :, :] = cv.logPolar(stim_left[frame], center_left, M, cv.WARP_FILL_OUTLIERS )
    logpolar_stim_right[frame, :, :] = cv.logPolar(stim_right[frame], center_right, M, cv.WARP_FILL_OUTLIERS )
    
    logpolar_stim_right[frame] = np.fliplr(logpolar_stim_right[frame])
    logpolar_stim[frame] = logpolar_stim_left[frame] + logpolar_stim_right[frame]
    
#     recovered_stim[frame, :, :] = cv.logPolar(logpolar_stim[frame, :, :], center, M, cv.WARP_INVERSE_MAP + cv.WARP_FILL_OUTLIERS)

# %% [markdown]
# ### Plot of overall activated neuronal field and recoverd stimulus

# %%
fig = plt.figure(figsize=(figSize, figSize))
shape2D = (stim.shape[1], stim.shape[2])
proj2D = np.zeros(shape2D)
for frame in range(nFrames):
    proj2D = proj2D + (logpolar_stim[frame, :, :]).reshape(shape2D)
    
plt.imshow(proj2D)

# %% [markdown]
# ### Animation of activation of visual cortex
# ![barStim.png](attachment:barStim.png)

# %%
fig = plt.figure(figsize=(figSize, figSize))
ax = plt.axes()  

# Animation function
def animate(i): 
    z = logpolar_stim[i,:,:]
    cont = plt.contourf(X, Y, z)
    return cont  

anim = animation.FuncAnimation(fig, animate, frames=nFrames)

anim.save('mappedStimulus.mp4', fps=1, codec='libx264')

with open('mappedStimulus.mp4', 'rb') as f:
    video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(base64.b64encode(f.read()).decode('utf-8'))
    
plt.close() 
HTML(video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %% [markdown]
# ## 1.3. Neuronal Responses
# First we need to assume the experiment parameters such as the TR and the event duration times. Then we can take the transformed stimulus frames as the boxcar neuronal responses.

# %%
TR = 3.0

neuronals_logpolar = np.zeros((nFrames*TRs, len(X), len(Y)))
neuronals_stim = np.zeros((nFrames*TRs, len(X), len(Y)))
t = np.arange(0,nFrames*TRs*TR,TR)

# extending the stimlus time to allow TRs for each event to get neuronals activations
for frame in range(nFrames):
    for i in range(TRs):
        neuronals_logpolar[frame*TRs + i, :, :] = logpolar_stim[frame, :, :]
        neuronals_stim[frame*TRs + i, :, :] = stim[frame, :, :]

# %% [markdown]
# ## Apply Assumed Model

# %%
x0 = [5, 5, 4]
x, y = np.mgrid[-radius:radius:precession, -radius:radius:precession]
pos = np.dstack((x, y))
mean = np.array([x0[0], x0[1]])
cov = np.array([[x0[2], 0], [0, x0[2]]])
rf = multivariate_normal(mean=mean, cov=cov)
model = rf.pdf(pos)
neuronals_model = stim_slow * model

# %% [markdown]
# ## 1.4. Hemodynamic Responses
# We can model the Hemodynamic response by assuming an LTI system and use the signle or double Gamma function as its impulse response.
# We can define the gamma distribution by providing its PDF:
# $$
# f_X(x) = \frac{\lambda^{\alpha} x^{\alpha-1} e^{-\lambda x}}{\Gamma(\alpha)} \hspace {5pt} x > 0\\
# \Gamma(\alpha) = \int_0^\infty x^{\alpha - 1} e^{-x} {\rm d}x, \hspace{20pt} \textrm{for }\alpha>0.
# $$
#
# Specifically, if $n \in \{1,2,3,...\}$, then
# $$
# \Gamma(n) = (n-1)!
# $$
#
#
# Therefore we can use a single shifted Gamma distribution with shape parameter n and rate $\lambda$ as the impulse reponse for the hemodynamic system,
# $$
# h(t) = \frac{\lambda^{n} (t-t_0)^{n-1} e^{-\lambda (t-t_0)}}{(n-1)!}
# $$

# %%
def hrf_single_gamma(t,n,lmbd,t0):
    return gamma.pdf(t,n,loc=t0,scale=lmbd)


def hrf_double_gamma(t,n1,n2,lmbd1,lmbd2,t01,t02,a):
    c = (gamma.cdf(t[t.size-1],n1,loc=t01,scale=lmbd1) 
        - a * gamma.cdf(t[t.size-1],n2,loc=t02,scale=lmbd2))
            
    return ( 1/c * (gamma.pdf(t,n1,scale=lmbd1,loc=t01) 
                   - a * gamma.pdf(t,n2,scale=lmbd2,loc=t02)) )

# %%
# parameters for double gamma distribution function hrf:
n1 = 4
lmbd1 = 2.0
t01 = 0
n2 = 7
lmbd2 = 3
t02 = 0
a = 0.3
hrf = hrf_double_gamma(t, n1, n2, lmbd1, lmbd2, t01, t02, a)

responses = np.zeros((nFrames*TRs, length, length))
for i in range(len(X)):
    for j in range(len(Y)):
        n = neuronals_model[:, i, j]
        responses[:, i, j] = np.convolve(hrf, n)[0:len(t)] + norm.rvs(scale=0.01, size=nFrames*TRs)

# %% [markdown]
# ### Plots of HRF and example Neuronal and Hemodynamic responses

# %%
plt.plot(t, hrf, color = 'black')
plt.xlabel('Time(sec)')
plt.ylabel('HRF')
plt.show()

neuronals_model
plt.plot(t, neuronals_model[:, 100, 70], color = 'black')
plt.xlabel('Time(sec)')
plt.ylabel('Example Neuronal response')
plt.show()


plt.plot(t, responses[:, 100, 70], color = 'black')
plt.xlabel('Time(sec)')
plt.ylabel('Example Hemodynamic Response')
plt.show()

# %% [markdown]
# ## 1.5. Downsampling the Hemodynamic Responses
# Here we downasmple the hemodynamic responses to get the fMRI rosultion.
#
# Let's say on average, the surface area of V1 is about 3000 $mm^3$ and the fMRI voxel sizes are 3x3x3 mm. Therefore there should be about a 1000 voxels in the fMRI data that corresponds to t30he V1 area. So let's downsample the cortical map into 30X30.

# %%
nVoxels = 30
bolds = np.zeros((nFrames*TRs, nVoxels, nVoxels))
for frame in range(nFrames*TRs):
    img = responses[frame, :, :]
    img_resized = resize(img, (nVoxels, nVoxels), mode='constant', preserve_range=True)
    bolds[frame, :, :] = img_resized

# %% [markdown]
# ### Animation of BOLD responses

# %%
fig = plt.figure(figsize=(figSize, figSize))
ax = plt.axes()  

X = Y = np.linspace(-radius, radius + precession, nVoxels)
# Animation function
def animate(i): 
    z = bolds[i,:,:]
    cont = plt.contourf(X, Y, z)
    return cont  

anim = animation.FuncAnimation(fig, animate, frames=nFrames*TRs)

anim.save('bolds.mp4', fps=TRs, codec='libx264')

with open('bolds.mp4', 'rb') as f:
    video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(base64.b64encode(f.read()).decode('utf-8'))
    
plt.close() 
HTML(video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %% [markdown]
# # 2. PRF Estimation

# %% [markdown]
# ![estimation.png](attachment:estimation.png)

# %% [markdown]
# ### Initialize the receptive field model

# %% [markdown]
# The probability density function for multivariate_normal is
# $$
# f(x) = \frac{1}{\sqrt{(2 \pi)^k \det \Sigma}} \exp\left( -\frac{1}{2} (x - \mu)^T \Sigma^{-1} (x - \mu) \right),
# $$
#
# where $\mu$ is the mean, $\Sigma$ the covariance matrix, and k is the dimension of the space where x takes values.

# %%
mean_init = [2, -2]
cov_init = np.array([[3, 0], [0, 3]])
rf_init = multivariate_normal(mean=mean_init, cov=cov_init)

# %%
fig = plt.figure(figsize=(figSize, figSize))
x, y = np.mgrid[-radius:radius:precession, -radius:radius:precession]
pos = np.dstack((x, y))
model = rf_init.pdf(pos)

# %% [markdown]
# ### PRF Response

# %%
pRF_Stim = np.zeros((nFrames*TRs, length, length))
pRF_Stim = stim_slow * model
rf_response = np.sum(np.sum(pRF_Stim, axis=1),axis=1)

# %%
fig = plt.figure(figsize=(figSize, figSize))
ax = plt.axes()  
X = Y = np.arange(-radius, radius , precession)
# Animation function
def animate(i): 
    z = pRF_Stim[i,:,:]
    cont = plt.contourf(X, Y, z)
    return cont  

anim = animation.FuncAnimation(fig, animate, frames=nFrames*TRs)

anim.save('pRF*Stimulus.mp4', fps=TRs, codec='libx264')

with open('pRF*Stimulus.mp4', 'rb') as f:
    video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(base64.b64encode(f.read()).decode('utf-8'))
    
plt.close() 
HTML(video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
prediction = np.convolve(rf_response, hrf)[:len(t)]

# %%
plt.plot(t, rf_response, color = 'black')
plt.xlabel('Time(sec)')
plt.ylabel('pRF response')
plt.show()

# %%
plt.plot(t, prediction, color = 'black')
plt.xlabel('Time(sec)')
plt.ylabel('BOLD Prediction')
plt.show()

# %% [markdown]
# ### Total Mean Squared Error Function

# %%
xVoxel = 22
yVoxel = 22
x, y = np.mgrid[-radius:radius:precession, -radius:radius:precession]
pos = np.dstack((x, y))
def MSE(x):
    mean = np.array([x[0], x[1]])
    cov = np.array([[x[2], 0], [0, x[2]]])
    rf = multivariate_normal(mean=mean, cov=cov)
    model = rf.pdf(pos)
    rf_response = np.sum(np.sum(stim_slow*model, axis=1),axis=1)
    prediction = np.convolve(rf_response, hrf)[:len(t)]
    return np.sum((bolds[:,xVoxel, yVoxel] - prediction)**2)/len(t)

# %% [markdown]
# ### Optimization

# %%
x0 = [0, 0, 1]
bnds = ((-radius, radius), (-radius, radius), (0.0001, 10))
res = minimize(MSE, x0, method='SLSQP', bounds=bnds)

# %%
res
# Out:
#      fun: 0.0001387863457516557
#      jac: array([0., 0., 0.])
#  message: 'Optimization terminated successfully.'
#     nfev: 60
#      nit: 12
#     njev: 12
#   status: 0
#  success: True
#        x: array([1.01e+01, 1.01e+01, 1.00e-04])
